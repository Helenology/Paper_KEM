# %%
import numpy as np
import matplotlib.pyplot as plt
from glob import glob
import SimpleITK as sitk
import tensorflow as tf
from tensorflow import keras
from keras.layers import AveragePooling3D
import time
import copy
from sklearn.cluster import KMeans
import pandas as pd
import gc
from sklearn.linear_model import LinearRegression
import math
import tensorflow as tf
from multiprocessing import Process, Manager
import datetime
import sys
import csv
import os
from tensorflow.keras.utils import to_categorical
from data_generate import *  # generate parameters and simulate data
from KEM_SIMU import *  # KEM class
from simulation_auxiliary import *  # bandwidth selection function
sys.path.append('../')
from utils import *

# %matplotlib inline

# %%
K = 3
# 数据的路径
lung_image_path = "/database/datasets/Classics/LUNA2016/IMAGES/"  # 存放CT的文件夹
lung_mask_path = "/database/datasets/Classics/LUNA16-Mask/"  # 存放肺部mask的文件夹
# the absolute paths of the CT files
lung_image_file_list = glob(lung_image_path + "*.mhd")

stats_dict = {'lung_image_path': lung_image_path,
              'lung_mask_path': lung_mask_path,
              'lung_image_file_list': lung_image_file_list,
              }

# %% [markdown]
# # Bandwidth Selection

# %% [markdown]
# - choose kernel sizes and bandwidth candidates for CV and REG methods
#
# - coefficients for CV: [0.5, 0.9, 1.3, 1.7, 2.1]

# %%
kernel_size_list = np.arange(3, 12, 2)

# CV: kernel size list and bandwidth candidate list
CV_kernel_size_list = []
CV_bandwidth_list = []
for kernel_size in kernel_size_list:
    for coef in np.arange(start=0.5, stop=2.5, step=2/5):
        CV_kernel_size_list.append(kernel_size)
        CV_bandwidth_list.append(kernel_size / 512 * coef)

# REG: kernel size list and bandwidth candidate list
REG_kernel_size_list = []
REG_bandwidth_list = []
for kernel_size in kernel_size_list:
    for coef in [1]:
        REG_kernel_size_list.append(kernel_size)
        REG_bandwidth_list.append(kernel_size / 512 * coef)

print(f"length of CV candidates: {len(CV_kernel_size_list)}")
print(f"length of REG candidates: {len(REG_kernel_size_list)}")

# save to stats_dict
stats_dict['CV_kernel_size_list'] = CV_kernel_size_list
stats_dict['CV_bandwidth_list'] = CV_bandwidth_list
stats_dict['REG_kernel_size_list'] = REG_kernel_size_list
stats_dict['REG_bandwidth_list'] = REG_bandwidth_list
# Out:
# length of CV candidates: 25
# length of REG candidates: 5

# %%
Ch_path = f"./Ch-{datetime.date.today().isoformat()}.csv"

with open(Ch_path, 'w', newline = '', encoding='utf-8') as f:
    csv_write = csv.writer(f)  
    csv_write.writerow([f"patient", "data_gen_time", "Ch_CV", "time_CV", "Ch_REG", "time_REG", "model.coef0", "model.coef1"])

# %%
# randomly select 100 patients for bandwidth selection
np.random.seed(0)
index_list = np.arange(0, len(lung_image_file_list), 1)
np.random.shuffle(index_list)
index_list = index_list[0:100]

# transform the dict so that it can be used in the following Process
manager = Manager()
stats_dict = manager.dict(stats_dict)

# %%
for index in index_list:
    np.random.seed(index)
    tf.random.set_seed(index)
    stats_dict['index'] = index
    process_eval = Process(target=compute_Ch_4_cv_reg, 
                           args=(stats_dict, Ch_path, 0.8))
    process_eval.start()
    process_eval.join()
# Out:
# ---------------WE ARE LOADING 150th PATIENT's CT with shape (292, 512, 512)...---------------
# 2023-10-30 03:51:32.661475: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 03:51:34.540041: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 6.0
# 2023-10-30 03:51:34.544238: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 15401 MB memory:  -> device: 1, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b4:00.0, compute capability: 6.0
# 2023-10-30 03:51:34.548038: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15401 MB memory:  -> device: 2, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b5:00.0, compute capability: 6.0
# 2023-10-30 03:51:34.551778: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 15401 MB memory:  -> device: 3, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b6:00.0, compute capability: 6.0
# Process Process-2:
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/KEM/KEM_simulation/simulation_auxiliary.py", line 53, in compute_Ch_4_cv_reg
#     pi, voxel_class = generate_pi_new_version(sample_CT_array, lung_mask_array, bone_threshold=400)
#   File "/KEM/KEM_simulation/data_generate.py", line 82, in generate_pi_new_version
#     voxel_class_tf = tf.reshape(tf.convert_to_tensor(voxel_class, dtype=tf.float32), pi_shape + (1,))
#   File "/root/miniconda3/envs/myconda/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/root/miniconda3/envs/myconda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py", line 102, in convert_to_eager_tensor
#     return ops.EagerTensor(value, ctx.device_name, dtype)
# tensorflow.python.framework.errors_impl.InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# 2023-10-30 03:51:45.225435: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 876.00MiB (rounded to 918552576)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-10-30 03:51:45.225522: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2023-10-30 03:51:45.225554: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225575: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225593: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225610: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225626: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225643: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225661: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225679: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225695: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225713: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225731: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225748: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225765: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225783: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225802: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225819: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225836: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225853: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225872: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225888: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225903: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:45.225945: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 876.00MiB was 256.00MiB, Chunk State:
# 2023-10-30 03:51:45.225963: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2023-10-30 03:51:45.225978: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 0B
# 2023-10-30 03:51:45.225994: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 0 memory_limit_: 4980736 available bytes: 4980736 curr_region_allocation_bytes_: 4980736
# 2023-10-30 03:51:45.226021: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                         4980736
# InUse:                               0
# MaxInUse:                            0
# NumAllocs:                           0
# MaxAllocSize:                        0
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-10-30 03:51:45.226038: W tensorflow/core/common_runtime/bfc_allocator.cc:474] <allocator contains no memory>
# ---------------WE ARE LOADING 406th PATIENT's CT with shape (147, 512, 512)...---------------
# 2023-10-30 03:51:47.444614: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 03:51:49.325765: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 6.0
# 2023-10-30 03:51:49.328001: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 15401 MB memory:  -> device: 1, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b4:00.0, compute capability: 6.0
# 2023-10-30 03:51:49.329643: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15401 MB memory:  -> device: 2, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b5:00.0, compute capability: 6.0
# 2023-10-30 03:51:49.331352: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 15401 MB memory:  -> device: 3, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b6:00.0, compute capability: 6.0
# Process Process-3:
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/KEM/KEM_simulation/simulation_auxiliary.py", line 53, in compute_Ch_4_cv_reg
#     pi, voxel_class = generate_pi_new_version(sample_CT_array, lung_mask_array, bone_threshold=400)
#   File "/KEM/KEM_simulation/data_generate.py", line 82, in generate_pi_new_version
#     voxel_class_tf = tf.reshape(tf.convert_to_tensor(voxel_class, dtype=tf.float32), pi_shape + (1,))
#   File "/root/miniconda3/envs/myconda/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py", line 153, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/root/miniconda3/envs/myconda/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py", line 102, in convert_to_eager_tensor
#     return ops.EagerTensor(value, ctx.device_name, dtype)
# tensorflow.python.framework.errors_impl.InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# 2023-10-30 03:51:59.681855: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 441.00MiB (rounded to 462422016)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-10-30 03:51:59.681948: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2023-10-30 03:51:59.681991: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682010: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682027: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682046: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682063: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682079: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682095: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682114: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682132: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682147: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682163: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682182: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682201: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682218: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682234: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682252: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682271: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682287: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682302: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682321: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682343: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 03:51:59.682381: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 441.00MiB was 256.00MiB, Chunk State:
# 2023-10-30 03:51:59.682397: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2023-10-30 03:51:59.682413: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 0B
# 2023-10-30 03:51:59.682428: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 0 memory_limit_: 4980736 available bytes: 4980736 curr_region_allocation_bytes_: 4980736
# 2023-10-30 03:51:59.682452: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                         4980736
# InUse:                               0
# MaxInUse:                            0
# NumAllocs:                           0
# MaxAllocSize:                        0
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-10-30 03:51:59.682469: W tensorflow/core/common_runtime/bfc_allocator.cc:474] <allocator contains no memory>
# ---------------WE ARE LOADING 513th PATIENT's CT with shape (110, 512, 512)...---------------
# 2023-10-30 03:52:01.692749: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 03:52:03.591151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:1d:00.0, compute capability: 6.0
# 2023-10-30 03:52:03.593430: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 15401 MB memory:  -> device: 1, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b4:00.0, compute capability: 6.0
# 2023-10-30 03:52:03.595154: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15401 MB memory:  -> device: 2, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b5:00.0, compute capability: 6.0
# 2023-10-30 03:52:03.596878: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 15401 MB memory:  -> device: 3, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b6:00.0, compute capability: 6.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_28530/780512792.py in <cell line: 1>()
#       6                            args=(stats_dict, Ch_path, 0.8))
#       7     process_eval.start()
# ----> 8     process_eval.join()
#
# ~/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# ~/miniconda3/envs/myconda/lib/python3.9/multiprocessing/popen_fork.py in wait(self, timeout)
#      41                     return None
#      42             # This shouldn't block if wait() returned successfully.
# ---> 43             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44         return self.returncode
#      45
#
# ~/miniconda3/envs/myconda/lib/python3.9/multiprocessing/popen_fork.py in poll(self, flag)
#      25         if self.returncode is None:
#      26             try:
# ---> 27                 pid, sts = os.waitpid(self.pid, flag)
#      28             except OSError:
#      29                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:

# %% [markdown]
# ## Re-Run the CT with Large Depth by Better GPU

# %%
# for i, index in enumerate(index_list):
#     # set random seed
#     np.random.seed(index)
#     tf.random.set_seed(index)
#     # read data and record its depth
#     stats_dict['index'] = index
#     sample_CT_path = stats_dict['lung_image_file_list'][index]
#     sample_CT_array, lung_mask_array = get_original_data_newversion(stats_dict['lung_image_path'], stats_dict['lung_mask_path'], sample_CT_path)
#     depth = sample_CT_array.shape[0]
#     info_list = [f"patient_{index}", depth]
#     # record results
#     with open("./optimal bwd csv/random100_all.csv", 'a', newline = '', encoding='utf-8') as f:
#         csv_write = csv.writer(f)  
#         csv_write.writerow(info_list)

# %%
# CT index and depth
random100 = pd.read_csv("./optimal bwd csv/random100_all.csv")
# results at hand
Ch_df = pd.read_csv(Ch_path)
# merge results; if NaN exists, then we need to re-run this row
random100_all = pd.merge(random100, Ch_df, how="left", on="patient")
random100_all
# Out:
#         patient  depth  data_gen_time     Ch_CV     time_CV    Ch_REG  \
# 0   patient_150    292      15.425414  0.139164  376.840242  0.238385
# 1   patient_406    147       7.923266  0.227100  260.861032  0.226362
# 2   patient_513    110       5.991382  0.217888  187.628968  0.214569
# 3   patient_101    197       9.840834  0.131556  334.943539  0.233110
# 4   patient_584    383      20.560244  0.144662  504.758250  0.250721
# ..          ...    ...            ...       ...         ...       ...
# 95  patient_382    127       7.421021  0.222407  224.812824  0.220602
# 96  patient_687    115       6.586531  0.219274  204.277602  0.217178
# 97  patient_475    116       6.816620  0.219546  202.712783  0.215272
# 98  patient_204    140       7.977019  0.225523  241.112269  0.220903
# 99  patient_506    183       9.884185  0.130178  318.482606  0.232306
#
#       time_REG  model.coef0   model.coef1
# 0   184.864365     0.071734  1.046064e-06
# 1    90.681398     0.181767  1.845100e-06
# 2    65.960526     0.142470  9.944276e-07
# 3   117.309187     0.150715  1.879123e-06
# 4   243.679065     0.182814  3.795135e-06
# ..         ...          ...           ...
# 95   77.938102     0.214699  1.819602e-06
# 96   71.249134     0.251859  1.913139e-06
# 97   71.737118     0.193411  1.381245e-06
# 98   83.966350     0.287176  2.457205e-06
# 99  109.400285     0.240150  2.922714e-06
#
# [100 rows x 9 columns]

# %%
rerun_df = random100_all.loc[np.isnan(random100_all.Ch_CV), ]
rerun_index_list = [int(item.split('_')[1]) for item in rerun_df.patient]

# %%
for index in rerun_index_list:
    np.random.seed(index)
    tf.random.set_seed(index)
    stats_dict['index'] = index
    process_eval = Process(target=compute_Ch_4_cv_reg, 
                           args=(stats_dict, CT_path, 0.8))
    process_eval.start()
    process_eval.join()

# %% [markdown]
# ## Estimation Accuracy Compare under Optimal Bandwidth

# %%
bdw_mse_path = f"./bdw_mse_df-{datetime.date.today().isoformat()}.csv"

with open(bdw_mse_path, 'w', newline = '', encoding='utf-8') as f:
    csv_write = csv.writer(f)  
    csv_write.writerow(["patient", "CV_pi_rmse", "CV_mu_rmse", "CV_sigma_rmse", 
                                   "REG_pi_rmse", "REG_mu_rmse", "REG_sigma_rmse"])

# %%
# CT index and depth
random100 = pd.read_csv("./optimal bwd csv/random100_all.csv")
# results at hand
Ch_df = pd.read_csv(Ch_path)
# merge results; no NaN exists
random100_all = pd.merge(random100, Ch_df, how="left", on="patient")

# compute optimal bandwidth
Ch_df = random100_all.dropna()
Ch_df['sample_size'] = (Ch_df['depth'] * 512 * 512 * 0.8).map(int)
Ch_df['bdw_CV'] = Ch_df['Ch_CV'] * Ch_df['sample_size'].map(lambda x: x**(-1/7))
Ch_df['bdw_REG'] = Ch_df['Ch_REG'] * Ch_df['sample_size'].map(lambda x: x**(-1/7))
Ch_df['index'] = [int(item.split('_')[1]) for item in list(Ch_df.patient)]
Ch_df.head()
# Out:
#        patient  depth  data_gen_time     Ch_CV     time_CV    Ch_REG  \
# 0  patient_150    292      15.425414  0.139164  376.840242  0.238385
# 1  patient_406    147       7.923266  0.227100  260.861032  0.226362
# 2  patient_513    110       5.991382  0.217888  187.628968  0.214569
# 3  patient_101    197       9.840834  0.131556  334.943539  0.233110
# 4  patient_584    383      20.560244  0.144662  504.758250  0.250721
#
#      time_REG  model.coef0   model.coef1  sample_size    bdw_CV   bdw_REG  \
# 0  184.864365     0.071734  1.046064e-06     61236838  0.010742  0.018401
# 1   90.681398     0.181767  1.845100e-06     30828134  0.019336  0.019273
# 2   65.960526     0.142470  9.944276e-07     23068672  0.019336  0.019042
# 3  117.309187     0.150715  1.879123e-06     41313894  0.010742  0.019035
# 4  243.679065     0.182814  3.795135e-06     80320921  0.010742  0.018618
#
#    index
# 0    150
# 1    406
# 2    513
# 3    101
# 4    584

# %%
bandwidth_mse_df = pd.read_csv(bdw_mse_path)

if bandwidth_mse_df.shape[0] > 0:  # run it the first time
    tmp_df = pd.merge(Ch_df, bandwidth_mse_df, how='left', on="patient")
    tmp_df = tmp_df.loc[np.isnan(tmp_df.CV_pi_rmse),]
else:  # rerun for large-depth CT data
    tmp_df = Ch_df
stats_dict['tmp_df'] = tmp_df
tmp_df
# Out:
# Empty DataFrame
# Columns: [patient, depth, data_gen_time, Ch_CV, time_CV, Ch_REG, time_REG, model.coef0, model.coef1, sample_size, bdw_CV, bdw_REG, index, CV_pi_rmse, CV_mu_rmse, CV_sigma_rmse, REG_pi_rmse, REG_mu_rmse, REG_sigma_rmse]
# Index: []

# %% [markdown]
# - may need to rerun with a better GPU for large-depth CT data

# %%
for i in range(len(tmp_df)):
    # 随机数种子
    index = tmp_df.iloc[i, ]["index"]
    np.random.seed(index)
    tf.random.set_seed(index)
    stats_dict['index'] = index
    stats_dict['i'] = i    
    process_eval = Process(target=compute_rmse_4_cv_reg, 
                           args=(stats_dict, bdw_mse_path))
    process_eval.start()
    process_eval.join()
    if process_eval.exitcode == 1:
        print(f"Failed with index:{index}")

# %%
# optimal bandwidth
Ch_df = pd.read_csv(Ch_path)
Ch_df = pd.merge(random100, Ch_df, how="left", on="patient")
Ch_df = Ch_df.dropna()

# rmse results based on the optimal bandwidth
bdw_mse_df = pd.read_csv(bdw_mse_path)

# merge the two dfs for complete data
complete_data = pd.merge(Ch_df, bdw_mse_df, how="left", on="patient")
# complete_data.to_csv('./complete_Ch_bwd_mse-2023-01-13.csv')
complete_data
# Out:
#         patient  depth  data_gen_time     Ch_CV     time_CV    Ch_REG  \
# 0   patient_150    292      15.425414  0.139164  376.840242  0.238385
# 1   patient_406    147       7.923266  0.227100  260.861032  0.226362
# 2   patient_513    110       5.991382  0.217888  187.628968  0.214569
# 3   patient_101    197       9.840834  0.131556  334.943539  0.233110
# 4   patient_584    383      20.560244  0.144662  504.758250  0.250721
# ..          ...    ...            ...       ...         ...       ...
# 95  patient_382    127       7.421021  0.222407  224.812824  0.220602
# 96  patient_687    115       6.586531  0.219274  204.277602  0.217178
# 97  patient_475    116       6.816620  0.219546  202.712783  0.215272
# 98  patient_204    140       7.977019  0.225523  241.112269  0.220903
# 99  patient_506    183       9.884185  0.130178  318.482606  0.232306
#
#       time_REG  model.coef0   model.coef1  CV_pi_rmse  CV_mu_rmse  \
# 0   184.864365     0.071734  1.046064e-06    0.042868    0.009482
# 1    90.681398     0.181767  1.845100e-06    0.023817    0.007346
# 2    65.960526     0.142470  9.944276e-07    0.027350    0.009342
# 3   117.309187     0.150715  1.879123e-06    0.043812    0.014145
# 4   243.679065     0.182814  3.795135e-06    0.041558    0.011599
# ..         ...          ...           ...         ...         ...
# 95   77.938102     0.214699  1.819602e-06    0.025684    0.008516
# 96   71.249134     0.251859  1.913139e-06    0.025235    0.009127
# 97   71.737118     0.193411  1.381245e-06    0.026651    0.008092
# 98   83.966350     0.287176  2.457205e-06    0.027840    0.010004
# 99  109.400285     0.240150  2.922714e-06    0.041723    0.009927
#
#     CV_sigma_rmse  REG_pi_rmse  REG_mu_rmse  REG_sigma_rmse
# 0        0.005703     0.028446     0.008415        0.004022
# 1        0.003916     0.023824     0.007366        0.003915
# 2        0.005849     0.027372     0.009303        0.005833
# 3        0.008411     0.028630     0.010465        0.004811
# 4        0.007792     0.025331     0.006615        0.004038
# ..            ...          ...          ...             ...
# 95       0.004347     0.025697     0.008533        0.004345
# 96       0.004566     0.025290     0.009177        0.004563
# 97       0.005679     0.026720     0.008080        0.005695
# 98       0.007842     0.027854     0.010036        0.007844
# 99       0.007033     0.023567     0.005325        0.003520
#
# [100 rows x 15 columns]

# %% [markdown]
# # Consistency实验

# %%
training_ratio_list = [0.10, 0.20, 0.50, 0.75, 1.00]
Ch = 0.2293052

manager = Manager()
stats_dict = manager.dict(stats_dict)

# %%
mse_path = f"./mse_results_DF-{datetime.date.today().isoformat()}.csv"

# if os.path.exists(mse_path) is True:
#     os.remove(mse_path)
with open(mse_path, 'w', newline = '', encoding='utf-8') as f:
    csv_write = csv.writer(f)  
    csv_write.writerow(["patient", "depth", "training_ratio", "kernel_size", "pi_rmse", "mu_rmse", "sigma_rmse"])

# %%
for index in range(len(lung_image_file_list)):
    # set random seed
    np.random.seed(index)
    tf.random.set_seed(index)
    stats_dict['index'] = index    
    process_eval = Process(target=compute_rmse_4_consistency, 
                           args=(stats_dict, mse_path,
                                 training_ratio_list, Ch,))
    process_eval.start()
    process_eval.join()
# Out:
# 2023-10-30 07:45:30.653168: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 07:45:33.434736: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b3:00.0, compute capability: 6.0
# 2023-10-30 07:45:33.436808: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 15401 MB memory:  -> device: 1, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b4:00.0, compute capability: 6.0
# 2023-10-30 07:45:33.438632: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15401 MB memory:  -> device: 2, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b5:00.0, compute capability: 6.0
# 2023-10-30 07:45:33.440423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 15401 MB memory:  -> device: 3, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b6:00.0, compute capability: 6.0
# 2023-10-30 07:45:35.698908: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# ------------- Ratio 0.1 -------------
# From function(__init__): Initialize mu via kmeans(with K=3)
# From function(__init__): Randomly pick 0.0998 positions for kmeans.
# From function(__init__): KMeans(with K=3) success, with time: 1.293 seconds
# 	centers: [1.0004517  0.6165712  0.06453138]
# From function(__init__): Initialize parameters successfully.
# 	pik_estimate:(3, 201, 512, 512, 1)
# 	pi_estimate: (3, 201, 512, 512, 1)
# 	mu_estimate: (3, 201, 512, 512, 1)
# 	sigma_estimate: (3, 201, 512, 512, 1)
# From function(__init__): Initialize kernel successfully.
# 	kernel: (11, 11, 11, 1, 1)
# From function(kem_algorithm): Receive max_steps: 50.
# ########################## STEP 0 ##########################
# +++ From m_step: add smooth_parameter to pik_estimate
# 	 Current pik difference: 0.222095
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 0.0283957
# 	 Current mu difference: 0.0010458
# 	 Current sigma difference: 0.00106291
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 0.0305044.
# ---This iteration step costs 31.6 seconds.---
# ########################## STEP 1 ##########################
# 	 Current pik difference: 0.000109026
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 7.83329e-06
# 	 Current mu difference: 7.28374e-06
# 	 Current sigma difference: 3.02193e-05
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 4.53363e-05.
# ---This iteration step costs 14.75 seconds.---
# 	Ultimate MSE: pi_rmse: 0.04581; mu_rmse: 0.01521; sigma_rmse: 0.01105
# ------------- Ratio 0.2 -------------
# From function(__init__): Initialize mu via kmeans(with K=3)
# From function(__init__): Randomly pick 0.05005 positions for kmeans.
# From function(__init__): KMeans(with K=3) success, with time: 0.9082 seconds
# 	centers: [1.0003833  0.6163356  0.06488246]
# From function(__init__): Initialize parameters successfully.
# 	pik_estimate:(3, 201, 512, 512, 1)
# 	pi_estimate: (3, 201, 512, 512, 1)
# 	mu_estimate: (3, 201, 512, 512, 1)
# 	sigma_estimate: (3, 201, 512, 512, 1)
# From function(__init__): Initialize kernel successfully.
# 	kernel: (11, 11, 11, 1, 1)
# From function(kem_algorithm): Receive max_steps: 50.
# ########################## STEP 0 ##########################
# +++ From m_step: add smooth_parameter to pik_estimate
# 	 Current pik difference: 0.221965
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 0.0276937
# 	 Current mu difference: 0.000966581
# 	 Current sigma difference: 0.00107249
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 0.0297328.
# ---This iteration step costs 14.76 seconds.---
# ########################## STEP 1 ##########################
# 	 Current pik difference: 0.000225894
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 5.33498e-06
# 	 Current mu difference: 6.17983e-06
# 	 Current sigma difference: 2.30209e-05
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 3.45357e-05.
# ---This iteration step costs 14.75 seconds.---
# 	Ultimate MSE: pi_rmse: 0.03636; mu_rmse: 0.01199; sigma_rmse: 0.00865
# ------------- Ratio 0.5 -------------
# From function(__init__): Initialize mu via kmeans(with K=3)
# From function(__init__): Randomly pick 0.02001 positions for kmeans.
# From function(__init__): KMeans(with K=3) success, with time: 3.042 seconds
# 	centers: [0.99999666 0.61484545 0.06506129]
# From function(__init__): Initialize parameters successfully.
# 	pik_estimate:(3, 201, 512, 512, 1)
# 	pi_estimate: (3, 201, 512, 512, 1)
# 	mu_estimate: (3, 201, 512, 512, 1)
# 	sigma_estimate: (3, 201, 512, 512, 1)
# From function(__init__): Initialize kernel successfully.
# 	kernel: (9, 9, 9, 1, 1)
# From function(kem_algorithm): Receive max_steps: 50.
# ########################## STEP 0 ##########################
# +++ From m_step: add smooth_parameter to pik_estimate
# 	 Current pik difference: 0.221587
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 0.0276669
# 	 Current mu difference: 0.000988082
# 	 Current sigma difference: 0.00109676
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 0.0297517.
# ---This iteration step costs 16.62 seconds.---
# ########################## STEP 1 ##########################
# 	 Current pik difference: 0.00057073
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 4.29187e-06
# 	 Current mu difference: 6.79948e-06
# 	 Current sigma difference: 1.98577e-05
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 3.0949e-05.
# ---This iteration step costs 8.223 seconds.---
# 	Ultimate MSE: pi_rmse: 0.03155; mu_rmse: 0.01051; sigma_rmse: 0.007457
# ------------- Ratio 0.75 -------------
# From function(__init__): Initialize mu via kmeans(with K=3)
# From function(__init__): Randomly pick 0.01337 positions for kmeans.
# From function(__init__): KMeans(with K=3) success, with time: 1.695 seconds
# 	centers: [1.0004572  0.6157774  0.06462137]
# From function(__init__): Initialize parameters successfully.
# 	pik_estimate:(3, 201, 512, 512, 1)
# 	pi_estimate: (3, 201, 512, 512, 1)
# 	mu_estimate: (3, 201, 512, 512, 1)
# 	sigma_estimate: (3, 201, 512, 512, 1)
# From function(__init__): Initialize kernel successfully.
# 	kernel: (9, 9, 9, 1, 1)
# From function(kem_algorithm): Receive max_steps: 50.
# ########################## STEP 0 ##########################
# +++ From m_step: add smooth_parameter to pik_estimate
# 	 Current pik difference: 0.221264
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 0.0274335
# 	 Current mu difference: 0.000972501
# 	 Current sigma difference: 0.00109935
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 0.0295054.
# ---This iteration step costs 8.228 seconds.---
# ########################## STEP 1 ##########################
# 	 Current pik difference: 0.000868219
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 3.77875e-06
# 	 Current mu difference: 6.58301e-06
# 	 Current sigma difference: 1.67888e-05
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 2.71505e-05.
# ---This iteration step costs 8.224 seconds.---
# 	Ultimate MSE: pi_rmse: 0.02834; mu_rmse: 0.0094; sigma_rmse: 0.00671
# ------------- Ratio 1.0 -------------
# From function(__init__): Initialize mu via kmeans(with K=3)
# From function(__init__): Randomly pick 0.009989 positions for kmeans.
# From function(__init__): KMeans(with K=3) success, with time: 1.803 seconds
# 	centers: [1.0005673  0.6154821  0.06487296]
# From function(__init__): Initialize parameters successfully.
# 	pik_estimate:(3, 201, 512, 512, 1)
# 	pi_estimate: (3, 201, 512, 512, 1)
# 	mu_estimate: (3, 201, 512, 512, 1)
# 	sigma_estimate: (3, 201, 512, 512, 1)
# From function(__init__): Initialize kernel successfully.
# 	kernel: (9, 9, 9, 1, 1)
# From function(kem_algorithm): Receive max_steps: 50.
# ########################## STEP 0 ##########################
# +++ From m_step: add smooth_parameter to pik_estimate
# 	 Current pik difference: 0.220949
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 0.0273573
# 	 Current mu difference: 0.00096391
# 	 Current sigma difference: 0.00109876
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 0.0294199.
# ---This iteration step costs 8.229 seconds.---
# ########################## STEP 1 ##########################
# 	 Current pik difference: 0.00116165
# From function(kem_algorithm): E step success.
# 	 Current pi difference: 3.46907e-06
# 	 Current mu difference: 6.51354e-06
# 	 Current sigma difference: 1.47904e-05
# From function(kem_algorithm): M step success.
# From function(kem_algorithm): difference: 2.4773e-05.
# ---This iteration step costs 8.222 seconds.---
# 	Ultimate MSE: pi_rmse: 0.02661; mu_rmse: 0.008841; sigma_rmse: 0.006323
# 2023-10-30 07:48:47.748240: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 07:48:50.643376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b3:00.0, compute capability: 6.0
# 2023-10-30 07:48:50.645046: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 193 MB memory:  -> device: 1, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b4:00.0, compute capability: 6.0
# 2023-10-30 07:48:50.646887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15401 MB memory:  -> device: 2, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b5:00.0, compute capability: 6.0
# 2023-10-30 07:48:50.648623: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 15401 MB memory:  -> device: 3, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b6:00.0, compute capability: 6.0
# 2023-10-30 07:48:53.553687: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# ------------- Ratio 0.1 -------------
# From function(__init__): Initialize mu via kmeans(with K=3)
# From function(__init__): Randomly pick 0.09997 positions for kmeans.
# From function(__init__): KMeans(with K=3) success, with time: 2.442 seconds
# 	centers: [1.0015941  0.45175412 0.04741291]
# From function(__init__): Initialize parameters successfully.
# 	pik_estimate:(3, 375, 512, 512, 1)
# 	pi_estimate: (3, 375, 512, 512, 1)
# 	mu_estimate: (3, 375, 512, 512, 1)
# 	sigma_estimate: (3, 375, 512, 512, 1)
# From function(__init__): Initialize kernel successfully.
# 	kernel: (11, 11, 11, 1, 1)
# From function(kem_algorithm): Receive max_steps: 50.
# ########################## STEP 0 ##########################
# Process Process-4:
# Traceback (most recent call last):
#   File "/root/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/root/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/mnt/KEM/KEM_simulation/simulation_auxiliary.py", line 252, in compute_rmse_4_consistency
#     kem.kem_algorithm(max_steps=50, epsilon=1e-4, smooth_parameter=1e-20)
#   File "/mnt/KEM/KEM_simulation/KEM_SIMU.py", line 93, in kem_algorithm
#     self.e_step(smooth_parameter)
#   File "/mnt/KEM/KEM_simulation/KEM_SIMU.py", line 114, in e_step
#     pik_estimate = normal_density_function_tf((self.training_data - self.mu_estimate) / self.sigma_estimate) * (
#   File "/mnt/KEM/KEM_simulation/../utils.py", line 91, in normal_density_function_tf
#     return 1 / tf.sqrt(2 * np.pi) * tf.exp(-x ** 2 / 2)
#   File "/root/miniconda3/envs/myconda/lib/python3.9/site-packages/tensorflow/python/ops/gen_math_ops.py", line 6753, in neg
#     _ops.raise_from_not_ok_status(e, name)
#   File "/root/miniconda3/envs/myconda/lib/python3.9/site-packages/tensorflow/python/framework/ops.py", line 7186, in raise_from_not_ok_status
#     raise core._status_to_exception(e) from None  # pylint: disable=protected-access
# tensorflow.python.framework.errors_impl.ResourceExhaustedError: failed to allocate memory [Op:Neg]
# 2023-10-30 07:49:53.854146: W tensorflow/core/common_runtime/bfc_allocator.cc:462] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.10GiB (rounded to 1179648000)requested by op Neg
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-10-30 07:49:53.854262: I tensorflow/core/common_runtime/bfc_allocator.cc:1010] BFCAllocator dump for GPU_0_bfc
# 2023-10-30 07:49:53.854299: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (256): 	Total Chunks: 9, Chunks in use: 9. 2.2KiB allocated for chunks. 2.2KiB in use in bin. 44B client-requested in use in bin.
# 2023-10-30 07:49:53.854326: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (512): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854353: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1024): 	Total Chunks: 1, Chunks in use: 1. 1.2KiB allocated for chunks. 1.2KiB in use in bin. 1.0KiB client-requested in use in bin.
# 2023-10-30 07:49:53.854378: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854404: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4096): 	Total Chunks: 1, Chunks in use: 1. 5.2KiB allocated for chunks. 5.2KiB in use in bin. 5.2KiB client-requested in use in bin.
# 2023-10-30 07:49:53.854429: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8192): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854453: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854476: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854501: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (65536): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854525: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854549: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854573: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (524288): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854636: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854661: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854684: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854708: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854733: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (16777216): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854757: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854781: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854804: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-10-30 07:49:53.854841: I tensorflow/core/common_runtime/bfc_allocator.cc:1017] Bin (268435456): 	Total Chunks: 18, Chunks in use: 15. 15.04GiB allocated for chunks. 13.55GiB in use in bin. 13.55GiB client-requested in use in bin.
# 2023-10-30 07:49:53.854875: I tensorflow/core/common_runtime/bfc_allocator.cc:1033] Bin for 1.10GiB was 256.00MiB, Chunk State:
# 2023-10-30 07:49:53.854916: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 374.99MiB | Requested Size: 0B | in_use: 0 | bin_num: 20, prev:   Size: 256B | Requested Size: 4B | in_use: 1 | bin_num: -1, next:   Size: 375.00MiB | Requested Size: 375.00MiB | in_use: 1 | bin_num: -1
# 2023-10-30 07:49:53.854948: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 401.75MiB | Requested Size: 16.11MiB | in_use: 0 | bin_num: 20, prev:   Size: 1.10GiB | Requested Size: 1.10GiB | in_use: 1 | bin_num: -1
# 2023-10-30 07:49:53.854982: I tensorflow/core/common_runtime/bfc_allocator.cc:1039]   Size: 750.00MiB | Requested Size: 375.00MiB | in_use: 0 | bin_num: 20, prev:   Size: 375.00MiB | Requested Size: 375.00MiB | in_use: 1 | bin_num: -1, next:   Size: 256B | Requested Size: 4B | in_use: 1 | bin_num: -1
# 2023-10-30 07:49:53.855005: I tensorflow/core/common_runtime/bfc_allocator.cc:1046] Next region of size 16149905408
# 2023-10-30 07:49:53.855040: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f942a000000 of size 1179648000 next 1
# 2023-10-30 07:49:53.855064: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9470500000 of size 1280 next 2
# 2023-10-30 07:49:53.855088: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9470500500 of size 256 next 3
# 2023-10-30 07:49:53.855111: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9470500600 of size 1179648000 next 4
# 2023-10-30 07:49:53.855133: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f94b6a00600 of size 1179648000 next 5
# 2023-10-30 07:49:53.855155: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f94fcf00600 of size 1179648000 next 7
# 2023-10-30 07:49:53.855177: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9543400600 of size 256 next 6
# 2023-10-30 07:49:53.855202: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9543400700 of size 393216000 next 8
# 2023-10-30 07:49:53.855224: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f955ab00700 of size 393216000 next 22
# 2023-10-30 07:49:53.855247: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f9572200700 of size 786432000 next 9
# 2023-10-30 07:49:53.855269: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1000700 of size 256 next 12
# 2023-10-30 07:49:53.855298: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1000800 of size 256 next 17
# 2023-10-30 07:49:53.855320: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1000900 of size 256 next 19
# 2023-10-30 07:49:53.855341: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1000a00 of size 256 next 20
# 2023-10-30 07:49:53.855363: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1000b00 of size 256 next 21
# 2023-10-30 07:49:53.855386: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1000c00 of size 5376 next 27
# 2023-10-30 07:49:53.855411: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1002100 of size 256 next 24
# 2023-10-30 07:49:53.855433: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95a1002200 of size 256 next 28
# 2023-10-30 07:49:53.855454: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f95a1002300 of size 393208832 next 13
# 2023-10-30 07:49:53.855476: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95b8700700 of size 393216000 next 14
# 2023-10-30 07:49:53.855503: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95cfe00700 of size 393216000 next 10
# 2023-10-30 07:49:53.855525: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f95e7500700 of size 1179648000 next 11
# 2023-10-30 07:49:53.855552: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f962da00700 of size 1179648000 next 15
# 2023-10-30 07:49:53.855574: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9673f00700 of size 1179648000 next 16
# 2023-10-30 07:49:53.855607: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f96ba400700 of size 1179648000 next 18
# 2023-10-30 07:49:53.855628: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9700900700 of size 1179648000 next 26
# 2023-10-30 07:49:53.855650: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f9746e00700 of size 1179648000 next 23
# 2023-10-30 07:49:53.855677: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] InUse at 7f978d300700 of size 1179648000 next 25
# 2023-10-30 07:49:53.855700: I tensorflow/core/common_runtime/bfc_allocator.cc:1066] Free  at 7f97d3800700 of size 421263616 next 18446744073709551615
# 2023-10-30 07:49:53.855725: I tensorflow/core/common_runtime/bfc_allocator.cc:1071]      Summary of in-use Chunks by size:
# 2023-10-30 07:49:53.855751: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 9 Chunks of size 256 totalling 2.2KiB
# 2023-10-30 07:49:53.855775: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-10-30 07:49:53.855798: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 1 Chunks of size 5376 totalling 5.2KiB
# 2023-10-30 07:49:53.855821: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 4 Chunks of size 393216000 totalling 1.46GiB
# 2023-10-30 07:49:53.855846: I tensorflow/core/common_runtime/bfc_allocator.cc:1074] 11 Chunks of size 1179648000 totalling 12.08GiB
# 2023-10-30 07:49:53.855874: I tensorflow/core/common_runtime/bfc_allocator.cc:1078] Sum Total of in-use chunks: 13.55GiB
# 2023-10-30 07:49:53.855896: I tensorflow/core/common_runtime/bfc_allocator.cc:1080] total_region_allocated_bytes_: 16149905408 memory_limit_: 16149905408 available bytes: 0 curr_region_allocation_bytes_: 32299810816
# 2023-10-30 07:49:53.855932: I tensorflow/core/common_runtime/bfc_allocator.cc:1086] Stats:
# Limit:                     16149905408
# InUse:                     14549000960
# MaxInUse:                  14549000960
# NumAllocs:                          93
# MaxAllocSize:               1179648000
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-10-30 07:49:53.855964: W tensorflow/core/common_runtime/bfc_allocator.cc:474] ***********************************___*__*********************************************************__
# 2023-10-30 07:49:53.856042: W tensorflow/core/framework/op_kernel.cc:1733] RESOURCE_EXHAUSTED: failed to allocate memory
# 2023-10-30 07:49:57.547108: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-30 07:50:00.912076: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b3:00.0, compute capability: 6.0
# 2023-10-30 07:50:00.913812: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 67 MB memory:  -> device: 1, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b4:00.0, compute capability: 6.0
# 2023-10-30 07:50:00.915600: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15401 MB memory:  -> device: 2, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b5:00.0, compute capability: 6.0
# 2023-10-30 07:50:00.917480: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1525] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 15401 MB memory:  -> device: 3, name: Tesla P100-SXM2-16GB, pci bus id: 0000:b6:00.0, compute capability: 6.0
# 2023-10-30 07:50:03.496190: I tensorflow/stream_executor/cuda/cuda_dnn.cc:368] Loaded cuDNN version 8101
# ------------- Ratio 0.1 -------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_73698/2351391614.py in <cell line: 1>()
#       8                                  training_ratio_list, Ch,))
#       9     process_eval.start()
# ---> 10     process_eval.join()
#
# ~/miniconda3/envs/myconda/lib/python3.9/multiprocessing/process.py in join(self, timeout)
#     147         assert self._parent_pid == os.getpid(), 'can only join a child process'
#     148         assert self._popen is not None, 'can only join a started process'
# --> 149         res = self._popen.wait(timeout)
#     150         if res is not None:
#     151             _children.discard(self)
#
# ~/miniconda3/envs/myconda/lib/python3.9/multiprocessing/popen_fork.py in wait(self, timeout)
#      41                     return None
#      42             # This shouldn't block if wait() returned successfully.
# ---> 43             return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#      44         return self.returncode
#      45
#
# ~/miniconda3/envs/myconda/lib/python3.9/multiprocessing/popen_fork.py in poll(self, flag)
#      25         if self.returncode is None:
#      26             try:
# ---> 27                 pid, sts = os.waitpid(self.pid, flag)
#      28             except OSError:
#      29                 # Child process not yet created. See #1731717
#
# KeyboardInterrupt:
